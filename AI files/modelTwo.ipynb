# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

Traindata = pd.read_csv("archive/train_u6lujuX_CVtuZ9i.csv")
X = Traindata.drop(columns=['Loan_Status'])
y = Traindata['Loan_Status']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)


#use this block A to test for a particular record
Gender = 1
Married = 0
Dependent = 0
Education = 1
SelfEmployed = 1
ApplicatIncome = 5489
CoApplicatIncome = 489
LoanAmount = 10000
LoanAmountTerms = 360
CreditHistory = 1
PropertyArea = 1
prediction = model.predict([[Gender,Married,Dependent,Education,SelfEmployed,ApplicatIncome,CoApplicatIncome,LoanAmount,LoanAmountTerms,CreditHistory,PropertyArea,]])
prediction
#Block A end


# use this block B to test for model accuracy
# prediction = model.predict(X_test)
# accuracy = accuracy_score(y_test, prediction)
# accuracy
# Block B end
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
import pickle

with open('pickle/pick_model_two.pickle','wb') as f:
    pickle.dump(model,f)
